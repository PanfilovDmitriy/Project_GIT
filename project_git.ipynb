# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b> Дмитрий, привет!👋</b>
#
# Меня зовут Кирилл Васильев, я буду ревьюером твоего проекта. Я предлагаю общаться на «ты», но если привычнее на «вы», просто скажи об этом!
#
# Я буду оставлять комментарии в твоем проекте. Пожалуйста, не удаляй их, они могут быть полезны в случае повторной проверки.
#
# Свои комментарии я буду обозначать <font color='green'>зеленым</font>, <font color='gold'>желтым</font> и <font color='red'>красным</font> цветами, например:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> В случае, если решение на отдельном шаге является полностью правильным. Здесь же я могу давать советы и предложения.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b> В случае, когда решение на отдельном шаге станет еще лучше, если внести небольшие коррективы.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#  В случае, когда решение на отдельном шаге требует существенной переработки и внесения правок. Напоминаю, что проект не может быть принят с первого раза, если ревью содержит комментарии, рекомендующие доработать шаги.
# </div>
#
# <br/>
# <div class="alert alert-info">
# Рекомендую для твоих комментариев использовать синий или любой другой цветной фон. Я постараюсь ничего не пропустить, но если комментарии будут выделены, то это мне очень поможет!
# </div>
#
# Увидев у тебя неточность, в первый раз я лишь укажу на ее наличие и дам тебе возможность самостоятельно найти и исправить ее. На реальной работе твой руководитель будет поступать также. Но если ты пока не справишься с такой задачей - при следующей проверке я дам более точную подсказку.

# %% [markdown]
# ## План выполнения проекта - Обучение с учителем
#
# Цель проекта:
# 1.  Разработайте модель, которая предскажет вероятность снижения покупательской активности.
# 2.	Выделить сегмент покупателей, проанализировать его и предложить, как увеличить его покупательскую активность
#
# Шаг 1. Загрузка данных для исследования.
# 1.1 Подключить необходимые библиотеки
# 1.2 Загрузить 4 таблицы с данными:
#
# Таблица 1: Данные о клиенте — market_file.csv
# •	id — номер покупателя в корпоративной базе данных.
# •	Покупательская активность — рассчитанный класс покупательской активности (целевой признак)
# •	Тип сервиса — уровень сервиса, например «премиум» и «стандарт».
# •	Разрешить сообщать — информация о том, можно ли присылать покупателю дополнительные предложения о товаре.
# •	Маркет_актив_6_мес — среднемесячное значение маркетинговых коммуникаций компании, которое приходилось на покупателя за последние 6 месяцев.
# •	Маркет_актив_тек_мес — количество маркетинговых коммуникаций в текущем месяце.
# •	Длительность — значение, которое показывает, сколько дней прошло с момента регистрации покупателя на сайте.
# •	Акционные_покупки — среднемесячная доля покупок по акции от общего числа покупок за последние 6 месяцев.
# •	Популярная_категория — самая популярная категория товаров у покупателя за последние 6 месяцев.
# •	Средний_просмотр_категорий_за_визит — показывает, сколько в среднем категорий покупатель просмотрел за визит в течение последнего месяца.
# •	Неоплаченные_продукты_штук_квартал — общее число неоплаченных товаров в корзине за последние 3 месяца.
# •	Ошибка_сервиса — число сбоев, которые коснулись покупателя во время посещения сайта.
# •	Страниц_за_визит — среднее количество страниц, которые просмотрел покупатель за один визит на сайт за последние 3 месяца.
# Таблица 2: Выручка — market_money.csv
# •	id — номер покупателя в корпоративной базе данных.
# •	Период — название периода, во время которого зафиксирована выручка.
# •	Выручка — сумма выручки за период.
#
# Таблица 3: Данные о времени — market_time.csv
# •	id — номер покупателя в корпоративной базе данных.
# •	Период — название периода, во время которого зафиксировано общее время.
# •	минут — значение времени, проведённого на сайте, в минутах.
#
# Таблица 4: Данные о прибыли — money.csv
# •	id — номер покупателя в корпоративной базе данных.
# •	Прибыль — значение прибыли.
#
# Шаг 2. Провести предварительную обработку данных
# 2.1 Изучить типы данных, преобразовать их при необходимости
# 2.2 Изучить пропуски в данных, заполнить при необходимости
# 2.3 Проверить наличие дублей, исправить данные при их обнаружении
#
# Шаг 3. Провести исследовательский анализ данных.
# 3.1 Статистический анализ всех признаков;
# 3.2 Построить графики;
# 3.3 Проанализировать выбросы
#
# Шаг 4. Объединить данные в одну таблицу.
# 4.1 Преобразовать таблицы - получить новые признаки
# 4.2 Удалить записи с пустыми признаками
# 4.3 Объединить таблицы
#
# Шаг 5. Корреляционный ализ данных
#
# Шаг 6. Отбор лучше модели
# 6.1 Построить пайплайн для четырех моделей с гиперпараметрами
# 6.2 Определить лучшую модель
#
# Шаг 7. Анализ важности признаков
#
# Шаг 8. Сегментация покупателей
# 8.1 Выполните сегментацию покупателей
# 8.2 Выберите группу покупателей и предложите, как увеличить её покупательскую активность:
# 8.3 Сделайте выводы о сегментах
#
# Шаг 9. Общий вывод

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера  <a class="tocSkip"> </h2>
#
# 👍 Цели, задачи и план ясны.
# </div>

# %% [markdown]
# ## Загрузка библиотек

# %%
# !pip install scikit-learn==1.2.2 -q
# !pip install matplotlib==3.5.1 -q
#!pip install -U scikit-learn 
# !pip install shap

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера  <a class="tocSkip"> </h2>
#
# 👍 Рекомендую во всех случаях использовать ключ -q для «тихой загрузки».
# </div>

# %% [markdown]
# <div style="background-color:#dce991; color:#black; padding:1%">
#     Спасибо. Принято

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера #2 <a class="tocSkip"> </h2>
#
# 👍 Cнова привет. Спасибо за заметное оформление твоих комментариев.
# </div>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import shap

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.model_selection import StratifiedKFold, GridSearchCV
# импортируем класс RandomizedSearchCV
from sklearn.model_selection import RandomizedSearchCV

#загружаем функцию для работы с метриками
from sklearn.metrics import (confusion_matrix,
                             roc_auc_score,
                             r2_score, 
                             mean_squared_error, 
                             mean_absolute_error,
                             recall_score,
                             precision_score,
                             accuracy_score)

# загружаем класс pipeline
from sklearn.pipeline import Pipeline

# загружаем классы для подготовки данных
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, StandardScaler, MinMaxScaler, RobustScaler, LabelEncoder
from sklearn.compose import ColumnTransformer

# загружаем класс для работы с пропусками
from sklearn.impute import SimpleImputer

# загружаем нужные модели
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC

RANDOM_STATE = 42
TEST_SIZE = 0.25

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Если загружаем несколько функций из одного пакета, то удобнее записать это через запятую.
#
# `from sklearn.metrics import r2_score, accuracy_score, precision_score, recall_score, confusion_matrix`
#
# А если через запятую будет больше трех-четырех позиций (а длина строки больше 90 символов), в таком случае здесь было бы идеально привести оформление в соответствие с <a href="https://pythonworld.ru/osnovy/pep-8-rukovodstvo-po-napisaniyu-koda-na-python.html">pep8</a> - не оставлять длинных строк.
#
# Такое оформление предпочтительнее:
#
# `from sklearn.metrics import (
#     accuracy_score,
#     confusion_matrix,
#     r2_score,
#     precision_score,
#     recall_score
# )`
#
#
# </div>

# %% [markdown]
# <div style="background-color:#dce991; color:#black; padding:1%">
#     Поправил

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера #2 <a class="tocSkip"> </h2>
#
# 👍 Отлично

# %% [markdown]
# ## Шаг 1. Загрузка данных
# 1.1 Загрузите данные.
# •	/datasets/market_file.csv
# •	/datasets/market_money.csv
# •	/datasets/market_time.csv
# •	/datasets/money.csv
# Обратите внимание: в некоторых файлах разделитель значений — точка с запятой, а разделитель десятичных значений — запятая.
# 1.2 Проверьте, что данные в таблицах соответствуют описанию. Исследованием и объединением данных вы займётесь позже.

# %%
#Зададим формат вывода данных ко всем данным типа float
pd.set_option('display.float_format', '{:.2f}'.format)

# %% [markdown]
# ### 1.1 Загрузка файла - market_file.csv

# %%
# Загрузка первой таблицы 
df_market = pd.read_csv('/datasets/market_file.csv')
#df_market = pd.read_csv('/datasets/market_file.csv', sep=";", decimal = ',')

# %%
df_market.head()
# Out:
#        id Покупательская активность Тип сервиса Разрешить сообщать  \
# 0  215348                 Снизилась     премиум                 да
# 1  215349                 Снизилась     премиум                 да
# 2  215350                 Снизилась   стандартт                нет
# 3  215351                 Снизилась   стандартт                 да
# 4  215352                 Снизилась   стандартт                нет
#
#    Маркет_актив_6_мес  Маркет_актив_тек_мес  Длительность  Акционные_покупки  \
# 0                3.40                     5           121               0.00
# 1                4.40                     4           819               0.75
# 2                4.90                     3           539               0.14
# 3                3.20                     5           896               0.99
# 4                5.10                     3          1064               0.94
#
#   Популярная_категория  Средний_просмотр_категорий_за_визит  \
# ...

# %%
df_market.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   1300 non-null   int64
#  1   Покупательская активность            1300 non-null   object
#  2   Тип сервиса                          1300 non-null   object
#  3   Разрешить сообщать                   1300 non-null   object
#  4   Маркет_актив_6_мес                   1300 non-null   float64
#  5   Маркет_актив_тек_мес                 1300 non-null   int64
#  6   Длительность                         1300 non-null   int64
#  7   Акционные_покупки                    1300 non-null   float64
#  8   Популярная_категория                 1300 non-null   object
#  9   Средний_просмотр_категорий_за_визит  1300 non-null   int64
#  10  Неоплаченные_продукты_штук_квартал   1300 non-null   int64
# ...

# %% [markdown]
# ### 1.2 Загрузка файла - market_money.csv

# %%
# Загрузка 2-ой таблицы - market_money.csv
df_revenue = pd.read_csv('/datasets/market_money.csv')

# %%
df_revenue.head()
# Out:
#        id               Период  Выручка
# 0  215348  препредыдущий_месяц     0.00
# 1  215348        текущий_месяц  3293.10
# 2  215348     предыдущий_месяц     0.00
# 3  215349  препредыдущий_месяц  4472.00
# 4  215349        текущий_месяц  4971.60

# %%
df_revenue.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       3900 non-null   int64
#  1   Период   3900 non-null   object
#  2   Выручка  3900 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 91.5+ KB

# %% [markdown]
# ### 1.3 Загрузка файла - market_time.csv

# %%
# Загрузка 3-ей таблицы - market_money.csv
df_time = pd.read_csv('/datasets/market_time.csv')

# %%
df_time.head()
# Out:
#        id            Период  минут
# 0  215348     текущий_месяц     14
# 1  215348  предыдцщий_месяц     13
# 2  215349     текущий_месяц     10
# 3  215349  предыдцщий_месяц     12
# 4  215350     текущий_месяц     13

# %%
df_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2600 entries, 0 to 2599
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      2600 non-null   int64
#  1   Период  2600 non-null   object
#  2   минут   2600 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 61.1+ KB

# %% [markdown]
# ### 1.4 Загрузка файла - money.csv

# %%
# Загрузка 4-ой таблицы - market_money.csv
df_profit = pd.read_csv('/datasets/money.csv', sep=";", decimal = ',')

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Всё верно по загрузкам.
#
# </div>

# %%
df_profit.head(2)
# Out:
#        id  Прибыль
# 0  215348     0.98
# 1  215349     4.16

# %%
df_profit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       1300 non-null   int64
#  1   Прибыль  1300 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 20.4 KB

# %% [markdown]
# <div style="background-color:lavender; color:#black; padding:1%">
#
# Были загружены 4 таблицы. Данные, содержащиеся в них соответствуют описанию

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 У нас данные внутренней аналитики, они действительно чаще бывают относительно чистыми. Дадасет качественный</div>

# %% [markdown]
# ## Шаг 2. Предобработка данных
# Проведите необходимую предобработку данных.
# Названия столбцов можно оставить кириллическими.

# %%
# Проверим на пропуски первую таблицу
df_market.isna().sum()
# Out:
# id                                     0
# Покупательская активность              0
# Тип сервиса                            0
# Разрешить сообщать                     0
# Маркет_актив_6_мес                     0
# Маркет_актив_тек_мес                   0
# Длительность                           0
# Акционные_покупки                      0
# Популярная_категория                   0
# Средний_просмотр_категорий_за_визит    0
# Неоплаченные_продукты_штук_квартал     0
# Ошибка_сервиса                         0
# Страниц_за_визит                       0
# dtype: int64

# %%
# Проверим на дубли
df_market[df_market.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, Покупательская активность, Тип сервиса, Разрешить сообщать, Маркет_актив_6_мес, Маркет_актив_тек_мес, Длительность, Акционные_покупки, Популярная_категория, Средний_просмотр_категорий_за_визит, Неоплаченные_продукты_штук_квартал, Ошибка_сервиса, Страниц_за_визит]
# Index: []

# %%
# Проверим уникальность значений категориальных признаков
print(df_market['Покупательская активность'].unique())
print(df_market['Тип сервиса'].unique())
print(df_market['Разрешить сообщать'].unique())
print(df_market['Популярная_категория'].unique())
#df_market['Тип сервиса'].value_counts()
# Out:
# ['Снизилась' 'Прежний уровень']
# ['премиум' 'стандартт' 'стандарт']
# ['да' 'нет']
# ['Товары для детей' 'Домашний текстиль' 'Косметика и аксесуары'
#  'Техника для красоты и здоровья' 'Кухонная посуда'
#  'Мелкая бытовая техника и электроника']

# %%
# Исправим данные в типе сервиса
df_market['Тип сервиса'].replace('стандартт', 'стандарт', inplace=True)
df_market['Тип сервиса'].value_counts()
# Out:
# стандарт    924
# премиум     376
# Name: Тип сервиса, dtype: int64

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Ага</div>

# %%
# Проверим уникальность значений категориальных признаков во второй таблице
print(df_revenue['Период'].unique())
# Out:
# ['препредыдущий_месяц' 'текущий_месяц' 'предыдущий_месяц']

# %%
# Проверим на пропуски 2-ую таблицу
df_revenue.isna().sum()
# Out:
# id         0
# Период     0
# Выручка    0
# dtype: int64

# %%
# Проверим на дубли
df_revenue[df_revenue.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, Период, Выручка]
# Index: []

# %%
# Проверим уникальность значений категориальных признаков в третьей таблице
print(df_time['Период'].unique())
# Out:
# ['текущий_месяц' 'предыдцщий_месяц']

# %%
# Проверим на пропуски 3-ю таблицу
df_time.isna().sum()
# Out:
# id        0
# Период    0
# минут     0
# dtype: int64

# %%
# Проверим на дубли
df_time[df_time.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, Период, минут]
# Index: []

# %%
# Проверим на пропуски 4-ую таблицу
df_profit.isna().sum()
# Out:
# id         0
# Прибыль    0
# dtype: int64

# %%
# Проверим на дубли
df_profit[df_profit.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, Прибыль]
# Index: []

# %% [markdown]
# <div style="background-color:lavender; color:#black; padding:1%">
#
# Проведена предварительная обработка данных.
# -    Проверены категориальные данные на уникальность. Поправлено 10 записей в перврй таблице по "Тип сервиса".
# -    Проверены пропуски в данных. Пропуски отсутствуют.
# -    Проверено дублирование данных. Явных дублей не выявлено

# %% [markdown]
# ## Шаг 3. Исследовательский анализ данных
# Проведите исследовательский анализ данных из каждой таблицы.
# Отберите клиентов с покупательской активностью не менее трёх месяцев, то есть таких, которые что-либо покупали в этот период.
# Оформите выводы по результатам шага.

# %%
#Получим статистические данные по первой таблице
df_market.describe()
# Out:
#              id  Маркет_актив_6_мес  Маркет_актив_тек_мес  Длительность  \
# count   1300.00             1300.00               1300.00       1300.00
# mean  215997.50                4.25                  4.01        601.90
# std      375.42                1.01                  0.70        249.86
# min   215348.00                0.90                  3.00        110.00
# 25%   215672.75                3.70                  4.00        405.50
# 50%   215997.50                4.20                  4.00        606.00
# 75%   216322.25                4.90                  4.00        806.00
# max   216647.00                6.60                  5.00       1079.00
#
#        Акционные_покупки  Средний_просмотр_категорий_за_визит  \
# count            1300.00                              1300.00
# mean                0.32                                 3.27
# std                 0.25                                 1.36
# min                 0.00                                 1.00
# ...

# %%
# Вывод графиков с чиловыми значениями
def draw_plots_num_1 (df): 
#Получить список столбцов с категориальными данными
    cat_col_names = df.select_dtypes(exclude='number').columns.tolist()
#Получить список столбцов с количествеными данными
    num_col_names = df.select_dtypes(include='number').columns.tolist()
    num_col_names = num_col_names[1:]
#Вывод графиков с количествеными данными
    sns.set_style("whitegrid") 
    for col in num_col_names:
        fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10,3))
        axes[1].set_title('Ящик с усами')
        axes[0].set_title('Гистограмма распределения ')
        sns.histplot(data=df, x=col, hue='Покупательская активность', bins=20, kde=True, ax=axes[0])
        sns.boxplot(data=df, x=col, hue='Покупательская активность', ax=axes[1])
        plt.show()

# %%
# График распределения с разделением целевого признака 1-ой таблицы
draw_plots_num_1 (df_market)

# %% [markdown]
# Видим явный сдвиг влево в графиках распределения для сниженой покупателькой активности в признаках: Страниц_за_визит и
# Маркетинговая активность 6 месяцев. Это говорит о том, что при снижении признака покупательская активность падает
# Видим явный сдвиг вправо в графике с признаком акционные покупки, указывающим на то, что его высокие значения связаны со снижением активности.

# %%
# Вывод графиков с категориальными данными
def draw_plots_cat (df, cat_1): 
#Получить список столбцов с категориальными данными
    cat_col_names = df.select_dtypes(exclude='number').columns.tolist()
    cat_col_names = cat_col_names[1:]
#Вывод графиков с категориальными данными
    sns.set_style("whitegrid") 
    for cat in cat_col_names:
        fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10,3))
        axes[1].set_title(cat)
        axes[0].set_title('Тепловая карта')
        
        df_piv = df.pivot_table(index=cat, columns=cat_1, values='id', aggfunc='count')
        sns.heatmap(df_piv, annot=True,  fmt='.0f', cmap='coolwarm', ax=axes[0])
        
        labels = df[cat].unique()
        plt.pie(df.value_counts(cat, ascending=False), autopct='%1.1f%%', labels = labels)
        plt.show()

# %%
# Вывод графиков с категориальными данными
draw_plots_cat (df_market, 'Покупательская активность')

# %% [markdown]
# Тепловые карты показывают значительные различия в покупательской активности в зависимости от категориального признака.

# %%
# Вывод графиков с чиловыми значениями
def draw_plots_num_2 (df): 
#Получить список столбцов с категориальными данными
    cat_col_names = df.select_dtypes(exclude='number').columns.tolist()
#Получить список столбцов с количествеными данными
    num_col_names = df.select_dtypes(include='number').columns.tolist()
    num_col_names = num_col_names[1:]
#Вывод графиков с количествеными данными
    sns.set_style("whitegrid") 
    for col in num_col_names:
        fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10,3))
        axes[1].set_title('Ящик с усами')
        axes[0].set_title('Гистограмма распределения ')
        sns.histplot(data=df, x=col,  bins=20, kde=True, ax=axes[0])
        sns.boxplot(data=df, x=col, ax=axes[1])
        plt.show()

# %%
# Исследуем данные второй таблицы
draw_plots_num_2 (df_revenue)

# %%
# Обнаружен выброс. Исследуем выброс в выручке
df_revenue[df_revenue['Выручка'] >= 80000]
# Out:
#         id         Период   Выручка
# 98  215380  текущий_месяц 106862.20

# %%
# Удалим выброс
df_revenue = df_revenue.query('Выручка < 80000')
print(df_revenue.shape)
# Out:
# (3899, 3)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍Все так</div>

# %%
# Построим графики второй таблицы еще раз
draw_plots_num_2 (df_revenue)

# %%
plt.title('Период') 
labels = df_revenue['Период'].unique()
plt.pie(df_revenue.value_counts('Период', ascending=False), autopct='%1.1f%%', labels = labels)
plt.show()

# %%
# Исследуем данные третьей таблицы
draw_plots_num_2 (df_time)
plt.title('Период') 
labels = df_time['Период'].unique()
plt.pie(df_time.value_counts('Период', ascending=False), autopct='%1.1f%%', labels = labels)
plt.show()

# %%
# Исследуем данные 4-ой таблицы
draw_plots_num_2 (df_profit)

# %% [markdown]
#
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Здесь сложночитаемый график. Хорошо бы как-то отделить матрицы друг от друга и подписать, чем они отличаются. Также важно будет прокомментировать, что полезного дает этот график.
#
# </div>

# %% [markdown]
# <div style="background-color:#dce991; color:#black; padding:1%">
#     Спасибо за замечанине. Понял, что диаграммы рассяния здесь мало помогут, так как целевой признак категориальный.
#     Диаграммы переделал. Разделенными по целевому признаку они стали гораздо информативнее.
#     Удалил блок с GRID, с которым познакомился в прошлом проекте. (очень хотелось использовать)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера #2 <a class="tocSkip"> </h2>
#
# 👍 Ок! Да, стало лучше.
#
# Про попробовать - с одной стороны, действительно полезно пробовать разное. С другой, лучше выбирать оптимальные графики, чтобы потом не исправлять при подготовке проекта к показу будущему работодателю.
#
# </div>

# %%
# Найдем клиентов с пропущеными периодами (выручка равна 0)
#del_id = df_revenue[df_revenue['Выручка']==0].groupby('id')['Выручка'].sum().
del_id = df_revenue[df_revenue['Выручка']==0]
list_del_id = del_id['id'].unique()
print(list_del_id)
# Out:
# [215348 215357 215359]

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Всё верно
#
# </div>

# %%
# Удалим этих клиентов из первой таблицы с клиентами
#df_market = df_market.drop ()
df_market = df_market[~ df_market["id"].isin(list_del_id)]
print('Размер таблицы с клиенами: ', df_market.shape)
# Out:
# Размер таблицы с клиенами:  (1297, 13)

# %% [markdown]
# <div style="background-color:lavender; color:#black; padding:1%">
#
# Проведен исследовательский анализ данных:
#     - Построены графики распредления и график "ящик с усами" для числовых величин и график "пирог" для категориальных
#     - Изучены статистические параметры в величин
#     - Построил диаграммы рассеяния для числовых параметров.
#     - Внимание привлекло распределение Акционных покупок в перврй таблице и выброс повыручки во второй. Строку с выбросом удалил.
#     - Отобрал клиентов с отсутствием активности в течении 3 месяцев по таблице с выручкой. Удалил трех клиенов из первой таблицы.

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Исследовательский анализ мы делаем для того, чтобы понять, какие закономерности заложены в наших данных. Здесь важно посмотреть на распределения признаков в разрезе целевого признака (снижения активности).
#
# Можно построить и наложить друг на друга гистограммы по данным в подвыборках с и без снижения активности. Можно расположить рядом два боксплота, для категориальных данных − две диаграммы.
#
# Думаю, так мы увидим гораздо больше интересной информации. Она нам особенно пригодится для части с исследованием сегмента покупателей.
#
# В этом проекте аналитическая составляющая достаточно серьезная. Если делаем анализ данных не только для подготовки признаков для моделей, но и для того, чтобы узнать новую информацию о бизнес-процессах, то исследование в разрезе целевого признака − решение по умолчанию.
#
# </div>

# %% [markdown]
# ## Шаг 4. Объединение таблиц
# 4.1 Объедините таблицы market_file.csv, market_money.csv, market_time.csv. Данные о прибыли из файла money.csv при моделировании вам не понадобятся.
# 4.2 Учитывайте, что данные о выручке и времени на сайте находятся в одном столбце для всех периодов. В итоговой таблице сделайте отдельный столбец для каждого периода.

# %%
# Сделаем сводную таблицу по id и периодам в файле с выручкой
df_revenue_period = df_revenue.pivot_table(index='id', columns='Период', values='Выручка', aggfunc='sum')
df_revenue_period.head(2)
# Out:
# Период  предыдущий_месяц  препредыдущий_месяц  текущий_месяц
# id
# 215348              0.00                 0.00        3293.10
# 215349           5216.00              4472.00        4971.60

# %%
# Изменим название столбцов в таблице df_revenue_period
(df_revenue_period.rename(columns = {'Период':'id',
                      'предыдущий_месяц':'выручка_предыдущий_месяц', 
                      'препредыдущий_месяц':'выручка_препредыдущий_месяц', 
                      'текущий_месяц':'выручка_текущий_месяц',
                      }, inplace = True )) 
df_revenue_period.head(2)
# Out:
# Период  выручка_предыдущий_месяц  выручка_препредыдущий_месяц  \
# id
# 215348                      0.00                         0.00
# 215349                   5216.00                      4472.00
#
# Период  выручка_текущий_месяц
# id
# 215348                3293.10
# 215349                4971.60

# %%
# Объединим
df_unit = df_market.merge(df_revenue_period, on='id', how='left')
print('Размер таблицы:', df_unit.shape)
df_unit.info()
# Out:
# Размер таблицы: (1297, 16)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1297 entries, 0 to 1296
# Data columns (total 16 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   1297 non-null   int64
#  1   Покупательская активность            1297 non-null   object
#  2   Тип сервиса                          1297 non-null   object
#  3   Разрешить сообщать                   1297 non-null   object
#  4   Маркет_актив_6_мес                   1297 non-null   float64
#  5   Маркет_актив_тек_мес                 1297 non-null   int64
#  6   Длительность                         1297 non-null   int64
#  7   Акционные_покупки                    1297 non-null   float64
#  8   Популярная_категория                 1297 non-null   object
#  9   Средний_просмотр_категорий_за_визит  1297 non-null   int64
# ...

# %%
# Сделаем сводную таблицу по id и периодам
print('Размер таблицы:', df_time.shape)
df_time_period = df_time.pivot_table(index='id', columns='Период', values='минут', aggfunc='sum')
print('Размер сводной таблицы:', df_time_period.shape)
df_time_period.head(2)
# Out:
# Размер таблицы: (2600, 3)
# Размер сводной таблицы: (1300, 2)
# Период  предыдцщий_месяц  текущий_месяц
# id
# 215348                13             14
# 215349                12             10

# %%
# Изменим название столбцов в таблице df_time_period
(df_time_period.rename(columns = {'Период':'id',
                      'предыдцщий_месяц':'минут_предыдущий_месяц', 
                      'текущий_месяц':'минут_текущий_месяц',
                      }, inplace = True )) 
df_time_period.head(2)
# Out:
# Период  минут_предыдущий_месяц  минут_текущий_месяц
# id
# 215348                      13                   14
# 215349                      12                   10

# %%
# Объединим df_unit с таблицей df_time_period
print('Размер таблицы до объединения:', df_unit.shape)
df_unit = df_unit.merge(df_time_period, on='id', how='left')
print('Размер таблицы после объединения:', df_unit.shape)
#df_unit.info()
# Out:
# Размер таблицы до объединения: (1297, 16)
# Размер таблицы после объединения: (1297, 18)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍  Хорошее решение, верный результат.
# </div>

# %%
# Проверим на пропуски полученную таблицу
df_unit.isna().sum()
# Out:
# id                                     0
# Покупательская активность              0
# Тип сервиса                            0
# Разрешить сообщать                     0
# Маркет_актив_6_мес                     0
# Маркет_актив_тек_мес                   0
# Длительность                           0
# Акционные_покупки                      0
# Популярная_категория                   0
# Средний_просмотр_категорий_за_визит    0
# Неоплаченные_продукты_штук_квартал     0
# Ошибка_сервиса                         0
# Страниц_за_визит                       0
# выручка_предыдущий_месяц               0
# выручка_препредыдущий_месяц            0
# выручка_текущий_месяц                  1
# минут_предыдущий_месяц                 0
# минут_текущий_месяц                    0
# dtype: int64

# %%
#  Удалим строчку с пропущенным значение (образовалась из-за удаления выброса)
df_unit = df_unit.dropna()
print('Размер таблицы после удаления пропусков:', df_unit.shape)
# Out:
# Размер таблицы после удаления пропусков: (1296, 18)

# %% [markdown]
# <div style="background-color:lavender; color:#black; padding:1%">
#
# Проведено обединие трех таблиц. Получили новую таблицу  df_unit.
# Для этого таблицы с выручкой и минутами были преобразованы сводной таблицей, с группировкой по клиентам и выделением новых признаков периодов.
# Было сделано левое присодинение данных.
# Проведена проверка на пропуски данных таблиц. Обнаружена одна запись. Принял решение ее удалить.

# %% [markdown]
# ## Шаг 5. Корреляционный анализ
# Проведите корреляционный анализ признаков в количественной шкале в итоговой таблице для моделирования.
# Сделайте выводы о мультиколлинеарности и при необходимости устраните её.

# %%
# преобразуем id  в индекс
df_unit = df_unit.set_index('id')

# %%
# построение тепловой карты корреляции.
#sns.heatmap(df_unit.corr(), annot=True, fmt='.2f', cmap='coolwarm' )
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(10,6))
sns.heatmap(df_unit.corr('spearman'), annot=True, fmt='.2f', cmap='coolwarm' ) 
plt.show()

# %% [markdown]
#
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Явно нужно увеличить график, чтобы что-то читалось.
#
# </div>

# %% [markdown]
# <div style="background-color:#dce991; color:#black; padding:1%">
#     Спасибо. Стало симпатичнее

# %% [markdown]
# <div style="background-color:lavender; color:#black; padding:1%">
#
# Проведен корреляционный анализ.
#     Использован метод Спирмена, так как не все параметры имеют распределене близкое к нормальному.
#     Анализ показал, что два параметра имеют близкую зависимость к колинеарному:
#     - выручка_предыдущий_месяц
#     - выручка_текущий_месяц
# Принял решение сохранить их, так как у них низкая связь с целевым признаком.

# %% [markdown]
# ## Шаг 6. Использование пайплайнов
# Примените все изученные модели. Для этого используйте пайплайны.
# 6.1 Во время подготовки данных используйте ColumnTransformer. Количественные и категориальные признаки обработайте в пайплайне раздельно. Для кодирования категориальных признаков используйте как минимум два кодировщика, для масштабирования количественных — как минимум два скейлера.
# Напоминаем, что для каждой модели можно подготовить данные с разным кодированием и масштабированием.
# 6.2 Обучите четыре модели: KNeighborsClassifier(), DecisionTreeClassifier(), LogisticRegression() и SVC(). Для каждой из них подберите как минимум один гиперпараметр. Выберите подходящую для задачи метрику, аргументируйте свой выбор. Используйте эту метрику при подборе гиперпараметров.
# 6.3 Выберите лучшую модель, используя заданную метрику. Для этого примените одну из стратегий:
# •	использовать пайплайны и инструменты подбора гиперпараметров для каждой модели отдельно, чтобы выбрать лучшую модель самостоятельно;
# •	использовать один общий пайплайн для всех моделей и инструмент подбора гиперпараметров, который вернёт вам лучшую модель.

# %%
# Создание списков для кодировщика
ohe_columns = ['Разрешить сообщать', 'Популярная_категория']
ord_columns = ['Тип сервиса']
num_columns = ['Маркет_актив_6_мес', 'Маркет_актив_тек_мес', 
               'Длительность', 'Акционные_покупки', 'Средний_просмотр_категорий_за_визит', 
               'Неоплаченные_продукты_штук_квартал', 'Ошибка_сервиса', 'Страниц_за_визит', 
               'выручка_препредыдущий_месяц','выручка_предыдущий_месяц','выручка_текущий_месяц' ,
               'минут_предыдущий_месяц', 'минут_текущий_месяц']
#num_columns1 = df_unit.select_dtypes(include='number').columns.tolist()
#print(num_columns1)

# выделим из таблицы целевой показатель
X = df_unit.drop(['Покупательская активность'], axis = 1)
y = df_unit['Покупательская активность']

# разделим на тренировочную и тестовую таблицу
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size = TEST_SIZE, 
    random_state = RANDOM_STATE )
print(y_test.value_counts())
# Out:
# Прежний уровень    198
# Снизилась          126
# Name: Покупательская активность, dtype: int64

# %% [markdown]
# Странное разделение таблицы на тренировочную и тестовую
# "снизилась" в общей базе - 62%
#             в тестовой   - 39%

# %%
# Закодирием целевую переменную
label_mapping = {'Снизилась': 1, 'Прежний уровень': 0}
label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(y_train.map(label_mapping))
y_test = label_encoder.transform(y_test.map(label_mapping))

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Отлично.
# </div>

# %%
# создаём пайплайн для подготовки признаков из списка ohe_columns: заполнение пропусков и OHE-кодирование
# SimpleImputer + OHE
ohe_pipe = Pipeline(
    [('simpleImputer_ohe', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
     ('ohe', OneHotEncoder(drop='first', handle_unknown='ignore', sparse=False))
    ]
    )

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Избегаем дамми-ловушку.
# </div>

# %%
# создаём пайплайн для подготовки признаков из списка ord_columns: заполнение пропусков и Ordinal-кодирование
# SimpleImputer + OE
ord_pipe = Pipeline(
    [('simpleImputer_before_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
     ('ord',  OrdinalEncoder(
                categories=[['стандарт', 'премиум']], 
                handle_unknown='use_encoded_value', unknown_value=np.nan
            )
        ),
     ('simpleImputer_after_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent'))
    ]
)

# %%
# создаём общий пайплайн для подготовки данных
data_preprocessor = ColumnTransformer(
    [('ohe', ohe_pipe, ohe_columns),
     ('ord', ord_pipe, ord_columns),
     ('num', MinMaxScaler(), num_columns)
    ], 
    remainder='passthrough'
)

# %%
# создаём итоговый пайплайн: подготовка данных и модель
pipe_final = Pipeline([
    ('preprocessor', data_preprocessor),
    ('models', DecisionTreeClassifier(random_state=RANDOM_STATE))
])

param_grid = [
    # словарь для модели DecisionTreeClassifier()
    {
        'models': [DecisionTreeClassifier(random_state=RANDOM_STATE)],
        'models__max_depth': range(2, 5),
        'models__max_features': range(2, 5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    },
    
    # словарь для модели KNeighborsClassifier() 
    {
        'models': [KNeighborsClassifier()],
        'models__n_neighbors': range(2, 5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']   
    },

    # словарь для модели LogisticRegression()
    {
        'models': [LogisticRegression(random_state=RANDOM_STATE)],
        'models__C': range(1, 5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    },
    
    # словарь для модели SVM()
    {
        'models': [SVC(random_state=RANDOM_STATE, probability= True)],
        'models__C': range(1, 10),
        'models__kernel': ['rbf', 'linear', 'sigmoid'],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    }
]

randomized_search = RandomizedSearchCV(
    pipe_final, 
    param_grid, 
    scoring='roc_auc',
    random_state=RANDOM_STATE,
    n_jobs=-1
)
randomized_search.fit(X_train, y_train)

print('Лучшая модель и её параметры:\n\n', randomized_search.best_estimator_)
print ('Метрика лучшей модели на тренировочной выборке:', randomized_search.best_score_)

# проверьте работу модели на тестовой выборке
# рассчитайте прогноз на тестовых данных
y_test_pred = randomized_search.predict(X_test)
print(f'Метрика ROC-AUC на тестовой выборке: {roc_auc_score(y_test, y_test_pred)}')
# Out:
# /opt/conda/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# /opt/conda/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# /opt/conda/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# ...

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Отлично, что используешь `remainder='passthrough'` . Хороший выбор гиперпараметров и значений для подбора. Отлично, что пробуем два типа масштабирования.
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# В тренажере была неточность. Строго говоря, выше выводишь качество не на тренировочной выборке (это когда на чем обучились, на том и предсказали), а на кросс-валидации. Внутри кросс-валидации у нас есть разделение на сплиты, часть из них (тренировочный сплит) участвует в обучении, тестовый (или валидационный) - в обучении не участвует, на нем мы оцениваем качество и подбираем гиперпараметры. Это все скрыто от нас внутри функции, но в итоге мы получаем некоторую приближенную к объективной оценку.
#
# Если же обучить модель на тренировочной выборке, а затем на ней же предсказать качество, то оно будет близко к 100%. Иногда такую оценку на тренировочной выборке используют для того, чтобы проверить, что модель вообще обучается.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера #2 <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>
#
# Ниже верно, а выше осталось ошибочное:
#
# ```
# # проверьте работу модели на тестовой выборке
# # рассчитайте прогноз на тестовых данных
# y_test_pred = randomized_search.predict(X_test)
# print(f'Метрика ROC-AUC на тестовой выборке: {roc_auc_score(y_test, y_test_pred)}')
#
#
#
# ```
#
# этот код нужно поправить или убрать.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2><s> Комментарий ревьюера <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>
#
# roc_auc нужно считать по вероятностям классов.
#
# `probabilities = model.predict_proba(features)
# probabilities_one = probabilities[:, 1]
# print('Площадь ROC-кривой:', roc_auc_score(target, probabilities_one))`
#
# Самое подробное объяснение метрики, что я видел на русском языке, можно посмотреть здесь: https://alexanderdyakonov.wordpress.com/2017/07/28/auc-roc-площадь-под-кривой-ошибок/
#
#
# </div>

# %%
from sklearn.metrics import RocCurveDisplay 
#получаем модель из пайплайна
model_best = randomized_search.best_estimator_.named_steps['models']

#получаем X_test из пайплайна
X_train_model = pd.DataFrame(
    pipe_final.named_steps['preprocessor'].fit_transform(X_train), 
    columns= pipe_final.named_steps['preprocessor'].get_feature_names_out())

X_test_model = pd.DataFrame(
    pipe_final.named_steps['preprocessor'].transform(X_test), 
    columns= pipe_final.named_steps['preprocessor'].get_feature_names_out())

#Рисуем график Roc-curve
RocCurveDisplay.from_estimator(model_best, X_test_model, y_test)

#Предсказанные вероятности снижения покупателькой активности
predicted = randomized_search.predict_proba(X_test)[:, 1]
print('Площадь ROC-кривой:', roc_auc_score(y_test, predicted))
# Out:
# Площадь ROC-кривой: 0.9012746512746511
# /opt/conda/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# /opt/conda/lib/python3.9/site-packages/sklearn/base.py:432: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(

# %% [markdown]
# <div style="background-color:#dce991; color:#black; padding:1%">
#     Спасибо за замечание.
#     Скопировал и даже не заметил, что не работает.
#     В проекте у меня была проблема, как получать данные из пайплайна, чтобы пользоваться изученными инструментами.
#     В упражнениях это опустили. Может быть есть хорошая ссылочка почитать об этом. Пока еще здесь чувствую себя не уверенно.

# %% [markdown]
# <div style="background-color:lavender; color:#black; padding:1%">
#
# Использован общий пайплайн для поиска лучшей модели.
#     - для этого определены параметры для кодирования и нормирования
#     - из данных выделен целевой признак и закодирован
#     - для оценки качества, выбрана метрика roc-auc, так как это универсальная метрика, подходящая для всех моделей и хорошо характеризующая их качество.
# Выбран случайный поиск лучшей модели, который определил логистическую регрессию с С=2, которая показала хорошую метрика ROC-AUC 0.9

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# `выбрана метрика roc-auc, так как это универсальная метрика, подходящая для всех моделей и хорошо характеризующая их качество.`
#
# А у нас есть неуниверсальные метрики, которые подходят не для всех моделей или плохо характеризуют их качество?
#
# Здесь, видимо, авторы подразумевали, что мы ответим про то, что мы выбрали не recall и не precision, а именно универсальную метрику, так как при подборе гиперпараметров важен баланс между полнотой и точностью.
#
# </div>

# %% [markdown]
# <div style="background-color:#dce991; color:#black; padding:1%">
#
# Метрику ROC-AUC интересна следующими свойствами:
#     - Устойчивость к несбалансированным классам.
#     - Независимость от выбранного порога вероятности.
#     - ROC-кривая позволяет визуализировать качество модели и сравнивать ее с другими моделями

# %% [markdown]
# ## Шаг 7. Анализ важности признаков
# 7.1 Оцените важность признаков для лучшей модели и постройте график важности с помощью метода SHAP.
# 7.2 Сделайте выводы о значимости признаков:
# •	какие признаки мало значимы для модели;
# •	какие признаки сильнее всего влияют на целевой признак;
# •	как можно использовать эти наблюдения при моделировании и принятии бизнес-решений.

# %%
#Определение лучшей модели
best_model = randomized_search.best_estimator_

#Получение закодированых признаков моделью
X_train_shap = pd.DataFrame(
    pipe_final.named_steps['preprocessor'].fit_transform(X_train), 
    columns= pipe_final.named_steps['preprocessor'].get_feature_names_out())

X_test_shap = pd.DataFrame(
    pipe_final.named_steps['preprocessor'].transform(X_test), 
    columns= pipe_final.named_steps['preprocessor'].get_feature_names_out())

#Загружаем в метод SHAP лучшую модел с признаками
model_shap = randomized_search.best_estimator_.named_steps['models']
explainer = shap.LinearExplainer(model_shap, X_train_shap)
shap_values = explainer(X_train_shap)
# Out:
# /opt/conda/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
#Получение коэффициентов логистической регрессии
coefficients = model_shap.coef_[0]
feature_importance = pd.DataFrame({'Feature': X_train_shap.columns, 'Importance': np.abs(coefficients)})
feature_importance = feature_importance.sort_values('Importance', ascending=True)
feature_importance.plot(x='Feature', y='Importance', kind='barh', figsize=(10, 6))
# Out:
# <AxesSubplot:ylabel='Feature'>

# %%
#Построим график общей значимости признаков:
shap.plots.bar(shap_values, max_display = 21)

# %%
#посмотрим, как признаки влияют на каждое предсказание модели:
shap.plots.beeswarm(shap_values, max_display = 21)

# %%
# Отберем одельные записи неверно классифицированных объектов. Для этого отфильтруем такие наблюдения по двум критериям:
X_test_df = X_test_shap
X_test_df['y_target'] = y_test.tolist()
X_test_df['predict_proba'] = randomized_search.predict_proba(X_test)[:, 1]
df_2 = X_test_df[(X_test_df['y_target']==1)&(X_test_df['predict_proba']<0.02)]
print(df_2.shape)
df_2.head()
# Out:
# (4, 22)
#      ohe__Разрешить сообщать_нет  \
# 78                          1.00
# 123                         1.00
# 141                         0.00
# 148                         1.00
#
#      ohe__Популярная_категория_Косметика и аксесуары  \
# 78                                              1.00
# 123                                             0.00
# 141                                             0.00
# 148                                             0.00
#
#      ohe__Популярная_категория_Кухонная посуда  \
# 78                                        0.00
# 123                                       0.00
# 141                                       0.00
# 148                                       0.00
#
#      ohe__Популярная_категория_Мелкая бытовая техника и электроника  \
# 78                                                0.00
# 123                                               0.00
# 141                                               0.00
# ...

# %%
#Оценка вклада каждого признака:
shap.plots.waterfall(shap_values[123], max_display = 21)

# %%
#print(pipe_final.named_steps['preprocessor'].get_feature_names_out())

# %% [markdown]
# <div style="background-color:lavender; color:#black; padding:1%">
#
# Проведена оценка важности признаков с помощью метода SHAP.
# Определены малозначимые признаки:
#     •	'ord__Тип сервиса'
#     •	'ohe__Популярная_категория_Косметика и аксесуары'
#     •	'num__Ошибка_сервиса'
#
# Определены наиболее значимые признаки:\
#     •	'num__Маркет_актив_6_мес'\
#     •	'num__минут_предыдущий_месяц'\
#     •	'num__Страниц_за_визит'\
#     •	'num__Акционные_покупки'
#
# При моделировании и принятии бизнесс-решений  следует обратить внимание на акционные покупки и Просмотр страниц за визит.
#     Как показал SHAP-анализ большая активность в акционных покупках увеличивает верояность, что клиент снизит свою активность до следующих интересных ему акций. Надо изменить акционную политику для исправления у потребитля охоты за акциями.
#     Просмотр страниц  потребителем удерживает клиента в активности. Следует подумать о дизайне страниц и увеличении ассортимента товаров.

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Количество времени, проводимое на сайте и число просмотренных страниц − это просто индикатор заинтересованности в покупках, но не причина активности в покупках.
#
# Это как в магазине количество покупок будет очень сильно коррелировать с числом зашедших покупателей и средним временем, которое покупатель проводит в магазине. Но просить покупателей зайти и выйти по три раза или подольше не уходить из магазина, чтобы увеличить формальное количество заходов в магазин или длительность нахождения точно не стоит, на покупки это не повлияет.
#
# В целом предложение «улучшить сайт» не выглядит таким, чтобы оно оказалось неверным. Однако здесь пока описанная тобой связь неочевидна, да и вполне может оказаться, что сайт постоянно улучшают и он вполне уже хорош.
#
# </div>

# %% [markdown]
# <div style="background-color:#dce991; color:#black; padding:1%">
#
# В бизнесе есть инструмент за контролем продаж называется воронкой продаж. Первое с чего начинается продажа это привлечь клиента на сайт, магазин, дилерский центр. И при правильной работе продавцов есть кореляция с количесвом продаж и количеством первого контакта с клиентом

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера #2 <a class="tocSkip"> </h2>
#
# 👍 С этим я согласен на 100%. Важно выбрать корректные инструменты привлечения. Вполне возможно, дизайн страниц − не первостепенно важная история в этом контексте. И самое главное, скорее всего за дизайн страниц отвечают другие люди и он не входит в зону нашей ответственности, если мы анализируем покупательское поведение клиента.
#
# </div>

# %% [markdown]
# ## Шаг 8. Сегментация покупателей
# 8.1 Выполните сегментацию покупателей. Используйте результаты моделирования и данные о прибыльности покупателей.
# 8.2 Выберите группу покупателей и предложите, как увеличить её покупательскую активность:
# •	Проведите графическое и аналитическое исследование группы покупателей.
# •	Сделайте предложения по работе с сегментом для увеличения покупательской активности.
# 8.3 Сделайте выводы о сегментах:
# •	какой сегмент вы взяли для дополнительного исследования,
# •	какие предложения вы сделали и почему.

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Здесь вместо описания задания я бы рекомендовал кратко описать, какой сегмент будем выбирать и чем он интересен бизнесу?
#
# </div>

# %% [markdown]
# <div style="background-color:#dce991; color:#black; padding:1%">
#
# Нас будет интересовать сегмент, который будет иметь наибольший риск для компании в снижении прибыли. Для оценки риска у нас есть два показателя: прибыль и верояность  снижения покапательской способности.
#
# Описание я привожу только для себя. Когда создаю структуру проета, сразу вставляю, из задания что надо делать. На этом экономлю время

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера #2 <a class="tocSkip"> </h2>
#
# 👍 По описанию согласен, действительно это удобно. Я бы из финальной версии его все равно убирал. Опять же, если будем показывать проект в портфолио, будет выгоднее смотреться, если здесь будут наши комментарии и наша логика, а не детальное описание проекта.
# </div>

# %%
# Постром матрицу ошибок. 
cm = confusion_matrix(y_test, y_test_pred)
print(cm)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues_r')
plt.ylabel('True label')
plt.xlabel('Predicted')
# Out:
# [[183  15]
#  [ 26 100]]
# Text(0.5, 15.0, 'Predicted')

# %%
#Предсказанные вероятности снижения покупателькой активности
predicted = randomized_search.predict_proba(X_test)[:, 1]
#Добавим вероянкость в тестовую таблицу
X_test['Вероятность'] = predicted
#X_test.reset_index(inplace=True)
#print(X_test.head())

# %%
#Добавим прибыль для последующей сегментации
df_seach = X_test.merge(df_profit, on = 'id')
#print(df_seach.head())

# %%
#Создадим новый признак РИСК равный произведению прибыли и вероятности снижения активности
df_seach['risk'] = df_seach['Вероятность']*df_seach['Прибыль']
#print(df_seach.sort_values(by='risk', ascending=False).head())

# %% [markdown]
# Посмотрим как расположились риски по популярным категоряим товаров, увидим наиболее рискованные категории

# %%
# Сделаем сводную таблицу по id и периодам в файле с выручкой. Определим рискованные группы
df_segment = df_seach.pivot_table(index='Популярная_категория', columns='Тип сервиса', values='risk', aggfunc='mean')
#print(df_segment)
sns.heatmap(df_segment, annot=True,  cmap='coolwarm')
# Out:
# <AxesSubplot:xlabel='Тип сервиса', ylabel='Популярная_категория'>

# %% [markdown]
# Создадим два дополнительных признака:
# 1. Разница в выручке предыдущего и препредыдущего месяца
# 2. Разница в выручке текущего и предыдущего месяца

# %%
#Разница в выручке предыдущего и предыдущего месяца  
df_seach['откл_предыдущий'] = df_seach['выручка_предыдущий_месяц'] -df_seach['выручка_препредыдущий_месяц']
#Разница в выручке текущего и предыдущего месяца 
df_seach['откл_текущий'] = df_seach['выручка_текущий_месяц'] - df_seach['выручка_предыдущий_месяц']

# %%
#Посмотрим как отклонения будут выглядеть по категориям 
df_div = df_seach.pivot_table(index='Популярная_категория', 
                                  values=['откл_предыдущий',
                                          'откл_текущий'], 
                                  aggfunc=[np.sum])
print(df_div)
# Out:
#                                                  sum
#                                      откл_предыдущий откл_текущий
# Популярная_категория
# Домашний текстиль                           19226.00     14787.50
# Косметика и аксесуары                       12169.00     16151.20
# Кухонная посуда                             18015.00     14216.80
# Мелкая бытовая техника и электроника         1635.50      8365.50
# Техника для красоты и здоровья             -13166.00     16233.20
# Товары для детей                           -10950.00     24044.80

# %%
#Отберем 25% ТОП риска и 75% более низкий
#количество записей в ТОП 25%
top_seg = int(round(0.25 * len(df_seach),0))
df_top_seg = df_seach.nlargest(top_seg, ['risk'])
top_list = df_top_seg['id']

# %%
#Те же отклонения в выбранном сенменте, высокого риска
df_div_risk = df_top_seg.pivot_table(index='Популярная_категория',  #columns='Тип сервиса',
                                  values=['откл_предыдущий','откл_текущий'], 
                                  aggfunc=[np.sum])
df_div_risk = df_div_risk.reset_index()
print(df_div_risk)
# Out:
#                    Популярная_категория             sum
#                                         откл_предыдущий откл_текущий
# 0                     Домашний текстиль         9796.50      3844.10
# 1                 Косметика и аксесуары         8031.00      6971.90
# 2                       Кухонная посуда        15084.00      7567.30
# 3  Мелкая бытовая техника и электроника         1180.50       941.20
# 4        Техника для красоты и здоровья        -1838.00      3008.20
# 5                      Товары для детей         3128.50      5708.30

# %%
#sns.scatterplot(data=df_div_risk, x="Популярная_категория", y="откл_предыдущий")

# %%
# Оставшиеся клиенты, оставшиеся после отбора повышенного риска
other_client = df_seach[~df_seach["id"].isin(set(top_list))]
print(df_seach.shape)
print(other_client.shape)
# Out:
# (324, 22)
# (243, 22)

# %%
df_div_risk = other_client.pivot_table(index='Популярная_категория', 
                                  values=['откл_предыдущий','откл_текущий'], 
                                  aggfunc=[np.sum])
print(df_div_risk)
# Out:
#                                                  sum
#                                      откл_предыдущий откл_текущий
# Популярная_категория
# Домашний текстиль                            9429.50     10943.40
# Косметика и аксесуары                        4138.00      9179.30
# Кухонная посуда                              2931.00      6649.50
# Мелкая бытовая техника и электроника          455.00      7424.30
# Техника для красоты и здоровья             -11328.00     13225.00
# Товары для детей                           -14078.50     18336.50

# %%
#Посмотрим на этих клиентов на диаграмме распределения -  карте риска
sns.scatterplot(x=df_seach['Вероятность'], y=df_seach['Прибыль'], label="Прочие клиенты", palette="deep")
sns.scatterplot(x=df_top_seg['Вероятность'], y=df_top_seg['Прибыль'], label="Рискованный сегмент", palette="deep")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Построим диаграммы распределения новых показателей с разделением на рисковый сегмент 
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15,3)) # создаем матрицу графиков и их размеры
fig.suptitle('Диаграммы распределения' )   
sns.histplot(data=other_client, x='откл_предыдущий', label="Прочие клиенты", ax=axes[0])
sns.histplot(data=df_top_seg, x='откл_предыдущий', label="Рискованный сегмент", color="orange", ax=axes[0])
sns.histplot(data=other_client, x='откл_текущий', label="Прочие клиенты", ax=axes[1])
sns.histplot(data=df_top_seg, x='откл_текущий', label="Рискованный сегмент", color="orange", ax=axes[1])
axes[0].set_title('Отклонение выручки М-1 ')
axes[1].set_title('Отклонение выручки М-0')
#axes[0].set_label(["Прочие клиенты", "Рискованный сегмент"])
#plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Распределение разницы выручки межу препредывущим и предыдущим периодом для изучаемого сегмента сдвинулось вправо (выручка чаще выросла), на другой разнице, такого эффекта нет.
# Изучим, есть ли зависимость с другими показателями

# %%
#Посмотрим на этих клиентов на диаграмме распределения двух отклонений
sns.scatterplot(x=df_seach['откл_предыдущий'], y=df_seach['откл_текущий'], label="Прочие клиенты", palette="deep")
sns.scatterplot(x=df_top_seg['откл_предыдущий'], y=df_top_seg['откл_текущий'], label="Рискованный сегмент", palette="deep")
#sns.scatterplot(x=df_top_seg['откл_предыдущий'], y=df_top_seg['risk'], label="Прочие клиенты", palette="deep")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Очень интересный график. Линейная зависимость для большинства точек. Это уже не случайный процесс. Рукотворные данне.
# Видим рост выручки в последние два месяца у рискованного сегмента. (Верхняя правая четверть больше оранжевых точек).
#
#
# Поищем зваисимости для выбранного сегмента среди других показатлей.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера #2 <a class="tocSkip"> </h2>
#
# 👍 Ага, здесь действительно «вылезли» сгенерированные данные.
# </div>

# %%
#factor = ['Маркет_актив_6_мес', 'Маркет_актив_тек_мес', 
#               'Длительность', 'Акционные_покупки', 'Средний_просмотр_категорий_за_визит', 
#               'Неоплаченные_продукты_штук_квартал', 'Ошибка_сервиса', 'Страниц_за_визит', 
#               'выручка_препредыдущий_месяц','выручка_предыдущий_месяц','выручка_текущий_месяц' ,
#               'минут_предыдущий_месяц', 'минут_текущий_месяц']
cat_col_names = ['Разрешить сообщать', 'Популярная_категория', 'Тип сервиса']
factor = ['Маркет_актив_6_мес', 'Маркет_актив_тек_мес', 
          'Длительность', 'Акционные_покупки', 
          'Средний_просмотр_категорий_за_визит' ]
for category in cat_col_names:
    g = sns.PairGrid(df_top_seg, hue = category, x_vars=factor, y_vars='risk')
    g.map(sns.scatterplot)
    g.add_legend()

# %%
cat_col_names = ['Разрешить сообщать', 'Популярная_категория', 'Тип сервиса']
factor = ['Неоплаченные_продукты_штук_квартал', 'Страниц_за_визит', 
          'выручка_препредыдущий_месяц','выручка_предыдущий_месяц','выручка_текущий_месяц' ,
          'минут_предыдущий_месяц'] 
for category in cat_col_names:
    g = sns.PairGrid(df_top_seg, hue = category, x_vars=factor, y_vars='risk')
    g.map(sns.scatterplot)
    g.add_legend()

# %% [markdown]
#  <div class="alert alert-block alert-danger">
# <h2><s> Комментарий ревьюера <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>
#
# Вплоть до этой части не вижу ни одного комментария. Не ясно, что и зачем делаем. Важно в начале обозначить, какой сегмент будем исследовать, аргументировать выбор. Здесь также важно комментировать графики − зачем строим, какую полезную инофрмацию извлекаем.
#
# Ниже также не вижу пояснений вплоть до вывода по разделу. Пока все это исследование нечитаемо.

# %% [markdown]
# Видно визуально, что клиенты со стандартным типом сервиса и с разрешением сообщать значительнго превышают другие значения.
# Проверим это на диаграмме распределения

# %%
#Проверим 
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15,3)) # создаем матрицу графиков и их размеры
fig.suptitle('Диаграммы распределения' )   
sns.histplot(data=df_top_seg, x='risk', hue='Тип сервиса', ax=axes[0])
sns.histplot(data=df_top_seg, x='risk', hue='Разрешить сообщать', ax=axes[1])
# Out:
# <AxesSubplot:xlabel='risk', ylabel='Count'>

# %% [markdown]
# Значимых измений распределения по категориальными признаками (Тип сервиса и Разрешить сообщить)не наблюдаем.
# Видим значительное превышение количество положительных ответов  в признаке Разрешить сообщить.

# %% [markdown]
# SHAP анализ выявил наиболее важние признаки влияния на снижение активности. Посмотрим как будум выглядить диаграмм распределения для выбранного сегмента

# %%
#Проверим 
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(8,2)) # создаем матрицу графиков и их размеры
fig.suptitle('Диаграммы распределения' )   
sns.histplot(data=other_client, x='Маркет_актив_6_мес', label="Все клиенты")
sns.histplot(data=df_top_seg, x='Маркет_актив_6_мес', label="Рискованный сегмент", color="orange")
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Проверим 
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(10,3)) # создаем матрицу графиков и их размеры
fig.suptitle('Диаграммы распределения' )   
sns.histplot(data=other_client, x='Страниц_за_визит', label="Все клиенты")
sns.histplot(data=df_top_seg, x='Страниц_за_визит', label="Рискованный сегмент", color="orange")
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Проверим 
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(8,2)) # создаем матрицу графиков и их размеры
fig.suptitle('Диаграммы распределения' )   
sns.histplot(data=other_client, x='Акционные_покупки', label="Все клиенты")
sns.histplot(data=df_top_seg, x='Акционные_покупки', label="Рискованный сегмент", color="orange")
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# На всех трех диаграммах мы видим сдвиги в рискованном сегменте, определенным SHAP-анализом.
#
# Посмотрим еще раз на доли категориальных признаков для выбранного сегмента.

# %%
# Функция для графиков
def draw_plots_dif (df, flag): 
#Получить список столбцов с категориальными данными
    cat_col_names = df.select_dtypes(exclude='number').columns.tolist()
#Получить список столбцов с количествеными данными
    num_col_names = df.select_dtypes(include='number').columns.tolist()
    num_col_names = num_col_names[1:]
#Вывод графиков с количествеными данными
    sns.set_style("whitegrid")
    if flag == "n":  
        for col in num_col_names:
            fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10,2))
            axes[1].set_title('Ящик с усами')
            axes[0].set_title('Гистограмма распределения ')
            sns.histplot(df[col], bins=20, kde=True, ax=axes[0])
            sns.boxplot(data=df, x=col, ax=axes[1])
            plt.show()
#Вывод графиков с категориальными данными        
    if flag == "c":
        for cat in cat_col_names:
            plt.title(cat) 
            labels = df[cat].unique()
            plt.pie(df.value_counts(cat, ascending=False), autopct='%1.1f%%', labels = labels)
            plt.show()
        
draw_plots_dif (df_top_seg, "c")

# %% [markdown]
# <div style="background-color:lavender; color:#black; padding:1%">
#
# Была проведна сегментация потребителей:
# 1. Для этого из четвертой таблицы добавлен признак прибыли, которую принес клиент компании.
# 2. Добавлен признак вероятность снижения активности из лучшей модели
# 3. Из них был создан новый признак риск, равный произведению этих двух показателей. Чем он выше, тем большие потери может понести компания. В сегмент отобрали ТОП 25% клиенов с максимальным риском.
#
# Выбранный сегмент был исследован.
# В рискованной группе значительно выросла:
#     для стандарта в Типе сервиса,
#     доля разрешений сообщать об активностях, в популярных категориях выросла для групп: Товары для детей, Косметика и аксессуары, Техника для красоты и здоровья.
#
# На совмещенных диаграммах распределения рискогого сегмента и прочего видо смещение:
#     - при росте Акционерных покупок в рисковую зону
#     - при снижении маркетинговой активности риск возрастает
#     - снижение количества страниц за визит в рискованную зону
# Чтобы не снижать покупательскую активность  необходимо поддерживать маркетинговые коммуникации компании с клиентом, пересмотреть
# мотивирование клиентов акциями, дольше удерживать клиента на сайте новым дизайном и интересным контестом.
# Наиболее популярные категории товаров - "Товары для детей" и "Косметика и аксессуары". Зничит основные клиенты женщины. Это надо учитывать при планировании акций и персональных предложений.

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# По выводам отлично. Важно будет добавить комментариев по ходу этого шага.
#
#
# Можно посчитать разницу в выручке между периодами для разных видов товаров, чтобы увидеть все в динамике. Понять, где проседаем, попытаться выяснить, почему.
#
# </div>

# %% [markdown]
# ## Шаг 9. Общий вывод
# Сделайте общий вывод:
# •	опишите задачу;
# •	опишите исходные данные и проведённую предобработку;
# •	напишите, что вы сделали для поиска лучшей модели;
# •	укажите лучшую модель;
# •	добавьте выводы и дополнительные предложения для выбранного сегмента покупателей.

# %% [markdown]
#  <div style="background-color:lavender; color:#black; padding:1%">
#
#    Интернет-магазин «В один клик» продаёт разные товары: для детей, для дома, мелкую бытовую технику, косметику и даже продукты. Отчёт магазина за прошлый период показал, что активность покупателей начала снижаться. Привлекать новых клиентов уже не так эффективно. О магазине и так знает большая часть целевой аудитории. Возможный выход — удерживать активность постоянных клиентов. Сделать это можно с помощью персонализированных предложений. «В один клик» — современная компания, поэтому её руководство не хочет принимать решения просто так — только на основе анализа данных и бизнес-моделирования. Руковдство решило  разработать решение, которое позволит персонализировать предложения постоянным клиентам, чтобы увеличить их покупательскую активность. Для этого были отобраны признаки, изложенные на диаграмме Иссикавы, которые нужно использовать в модели.
#
#    Исходные данные состоят из 4 файлов. В первом содержаться даные о клиенте и большинство признаков. В втором и третьем файле выручка и время проведенное на сайте. Из этих данных будут строиться дополнительные признаки для исследования.
#
#    Была проведена предварительная обработка данных. Данные были проверены на ошибки, дубликаты, пропуски. Исправлена ошибка 10 записях признака Тип сервиса. Пропусков в датасетах не было.
#
#    Был проведен исследовательский анализ данных. Построены графики распредления и график "ящик с усами" для числовых величин и график "пирог" для категориальных. Обнаружен и удален один выброс в выручке второго файла.
#
#    Отобрны клиентов с отсутствием активности в течении 3 месяцев по таблице с выручкой и удалены три клиента из первой таблицы. Обработаны вторая и третья таблица для получения новых признаков. Эти признаки были добавлены в первую таблицу с склиентами.
#
#    Для поиска лучшей модели был использован пайплайн, в котором перебирались 4 модели со своими гиперпараметрами, способы масштабирования данных по случайному алгоритму. Лучшей моделью оказалась - логистическая регрессия с С=2, которая показала хорошую метрику ROC-AUC 0.9
#
#    Были определены признаки, которые наибольшим образом влияют на целевой признак - снижение покупательной активности:
# 'num__Маркет_актив6мес', 'num__минут_предыдущий_месяц',  'num__Страниц_за_визит',  'num__Акционные_покупки'.
#     При чем рост показателя Акционные покупки увеличивает вероятность снижения активности.
#     Добавив в тестовую таблицу вероятность целевого признака и сумму прибыли, получили признак риска, который позволил отобрать
# сегмент, который  может принести наибольшие убытки компании.
#     При принятии бизнес решений хочется порекомендовать внимательнее относится к проведению акционных компаний, не снижать маркетинговую активность, удерживать внимание клиента на сайте дизайном, ассортиментом и прочими фишками.
#     Клиенты премиум-подписки реже попадают в зону риска, поэтому стоит мотивировать клиентов ее оформлять.
#     Наибольший риск снижения активности в категории товаров - "Товары для детей" и "Косметика и аксессуары", поэтому внимание в первую очередь должно быть сосредоточено на них.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍  `Наибольший риск снижения активности в категории товаров - "Товары для детей" и "Косметика и аксессуары", поэтому внимание в первую очередь должно быть сосредоточено на них.` - по этой рекомендации отлично.
#
# Думаю, если исследуем категории в динамике по периодам, еще уточним информацию.
# </div>

# %% [markdown]
#
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# `Акционные покупки увеличивает вероятность снижения активности.` - а есть гипотеза, почему? Не кажется странным, что снижают активность именно те, кто почти все покупают по акции. Как можно объяснить такое поведение?
#
# `При принятии бизнес решений хочется порекомендовать внимательнее относится к проведению акционных компаний, не снижать маркетинговую активность, удерживать внимание клиента на сайте дизайном, ассортиментом и прочими фишками.` - здесь слишком широкая рекомендация. Примерно как если рекомендовать маркетплейсу лучше продавать товары и извлекать больше прибыли. В реальной аналитике стоит избегать таких широких формулировок, они несут нулевую информацию.
#
# Прочитав или услышав такую рекомендацию, руководитель не сможет использовать ее для принятия решений. То есть, вряд ли акционные компании проводили не внимательно, а маркетинговую активность планировали снижать. По дизайну − здесь рекомендация спорная, наличие причинно-следственной связи якобы плохого дизайна и того, что клиент «мало просматривает страниц» не прослеживается.
#
# Я бы по каждому пункту кратко описал, что показывают данные, какая есть проблема и как ее можно решить. Вот, например, как у тебя написано в этом пункте:
#
# `Клиенты премиум-подписки реже попадают в зону риска, поэтому стоит мотивировать клиентов ее оформлять.` - здесь обозначена проблема, мы ее видели в данных, есть предложение по улучшению.
#
# </div>

# %% [markdown]
# <div style="background-color:#dce991; color:#black; padding:1%">
#
# У меня следующее объяснение снижение активности при росте акционных покупок - компания своей акционной политикой (размером скидок, условиями проведения) привлекла на сайт особую категорию потребителей, которая охотится за скидками и покупает только товары по хорошим акциям. И если вдруг компания, снижает скидки или ухудшает условия эти потребители ищут лучшие условия в других компаниях. Лояльность клиентов к компании видимо не высокая, вот и превлекают клиентов скидками, ухудшая свою прибыльность. Это доказывает как раз робастное поведение премиум подписки.
#
# В Этом проекте, мне многое кажется странным и не находит логичных объяснений.
# Уже с постановки задания. Откуда взялся целевой признак, снижение покупательской способности? Как он был получен?
# Много графиков без объяснений. Полностью согласен с этим замечанием. Их было построено раза в 4 больше. Но никак не получается, что то в них рассмотреть, чтобы делать логичные умозаключения.
# В каждый бизнес нужно вживаться, в этот у меня получилось плохо. Чтобы давать советы этой компании, глядя на цифры, еще нужно посмотреть на ее бизнес процессы. Поэтому и рекомендации у меня общего плана.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера #2 <a class="tocSkip"> </h2>
#
# 👍 От нас здесь и требуются рекомендации общего плана. Важно показать, что мы видим за данными смысл, даже в условиях ограниченной информации. По рекомендациям у тебя все сильно лучше, чем у подавляющего числа тех, кто выполняет этот проект.
#
# По графикам - это нормально, если в процессе выполнения проекта мы строим много дополнительных и некоторое количество лишних графиков, которые не дают нам информации. Но желательно в финальной версии проекта оставлять те, которые оказались важными. Конечно, хочется продемонстрировать, что проделана большая работа, но все-таки важнее здесь оформить максимально информативный и без визуального мусора документ по проекту.
#
# По целевому признаку - все так, здесь хочется получить точное представление о первоначальной формуле расчета снижения активности. Мы исходим из того, что оно было адекватным и строим модель, которая переводит классы в вероятности классов. С ней мы уже как бы восстанавливаем закономерности, как и в каких случаях клиенты снижают активность.
#
# Вообще же тут классическая задача оттока. Просто в нашем случае клиент не разрывает никаких договоров, не прекращает выплаты по подписке, так что нет четкого события, которое говорит об оттоке. Поэтому мы заменяем слово «отток» снижением активности. Как правило, для измерения применяется некоторый признак или сумма признаков, обладатели которых в 95% (или другом проценте) случаев в дальнейшем не пользуются сервисом. Условно говоря, если клиент ничего не купил за последние 2-3 месяца, то с очень высокой вероятностью он не купит ничего в последующий год. Возможно, в случае с маркетплейсами метрика будет более мягкой (например, допускать какое-то минимальное число покупок).
#
# По объяснению снижения активности у «акционщиков» мы с тобой совпали на 100%. Мне также кажется, что это наиболее вероятное объяснение.
#
#
# </div>

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# **Общий вывод по проекту**
#
# Спасибо за твой проект! Эта работа также была достаточно объемной и требовала концентрации внимания. По структуре проекта, логичности действий и общему подходу все замечательно, что не может не радовать.
#
# **Отмечу положительные моменты проекта🚀**
#
# * Хорошие решения в коде, есть пояснения и аргументации.
# * Грамотная предобработка и подготовка признаков.
# * Корректное обучение моделей, использование пайплайнов.
#
#
# **На что стоит обратить внимание🤔**
#
# * Важно в исследовательском анализе рассмотреть отдельно подвыборки для клиентов со снижающейся и с постоянной активностью (делим по целевому признаку). Выводим портрет клиента со снижающейся активностью.
# * Необходимо уточнить аргументацию выбора метрики качества.
# * Важно пересчитать ROC_AUC по вероятностям классов.
# * В исследовании сегмента важно добавить комментариев по ходу самого исследования. Пока вижу лишь цифры, графики и вывод.
# * Рекомендую также углубить и исследование сегмента: там, где можем, смотрим на динамику в категориях товаров.
# * Желательно уточнить рекомендации заказчику в сторону большей конкретики: опираясь на данные описываем проблему и то, как ее можно решать.
# * Эти и остальные замечания я также написал по ходу проекта.
#
# **Желаю удачи и жду твой проект на повторное ревью!**😉
#
#
# </div>

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# **Комментарий ко второй проверке**
#
# Спасибо за доработку. Критичных комментариев нет.
#
# Если что-то пропустил или остались вопросы, напиши в телеграм @kriill
#
# Желаю удачи в дальнейшей учебе!
#
# </div>

# %%
# !ls
# Out:
#  02e82b61-b89f-4081-98ff-09ebf82751d1.ipynb
#  121212.ipynb
#  34d86e33-7bb8-44d5-9fa7-f9e32694f28a.ipynb
#  5703a051-bd41-4796-af62-9a0a2bf2ac07.ipynb
#  5ce83761-8ccf-49d0-b811-594389520d4b.ipynb
#  6578cd52-d561-4374-81e1-8d0f359004c8.ipynb
#  6d57a9f0-1242-4990-957a-74122ecd3a2b.ipynb
#  7ac2572b-a8e6-454b-8798-1b1540012dd2-Copy1.ipynb
#  7ac2572b-a8e6-454b-8798-1b1540012dd2.ipynb
#  a58bcfbc-e264-4b7b-8f2e-194c4281ff8b.ipynb
#  bd7fd133-3735-4f36-ba23-87a0601d1c19.ipynb
#  c0909394-c4fc-492d-bbfb-613cce27467e.ipynb
# 'D:\LocalData\Y108354\Documents\Плановая работа\Кузьменко\Яндекс Учеба\fff.ipynb'
# 'D:\LocalData\Y108354\Documents\Плановая работа\Кузьменко\Яндекс Учеба\ppp.ipynb'
# 'D:\LocalData\Y108354\Documents\Плановая работа\Кузьменко\Яндекс Учеба\Проект 7.ipynb'
# 'D:\LocalData\Y108354\Documents\Плановая работа\Кузьменко\Яндекс Учеба\Проект 7\proekt7.ipynb'
#  eb585f0a-b4ac-4d4d-9520-283a3dea9cd8.ipynb
#  proba111.ipynb
#  proekt11
# 'Project GID.ipynb'
#  Untitled.ipynb

# %%
 # !$PWD
# Out:
# /bin/bash: /home/jovyan/work: Is a directory

# %%
! mkdir proekt11

# %%
! cd proekt11

# %%
! pyvenv my_env
# Out:
# /bin/bash: pyvenv: command not found

# %%
# !ls
# Out:
#  02e82b61-b89f-4081-98ff-09ebf82751d1.ipynb
#  121212.ipynb
#  34d86e33-7bb8-44d5-9fa7-f9e32694f28a.ipynb
#  5703a051-bd41-4796-af62-9a0a2bf2ac07.ipynb
#  5ce83761-8ccf-49d0-b811-594389520d4b.ipynb
#  6578cd52-d561-4374-81e1-8d0f359004c8.ipynb
#  6d57a9f0-1242-4990-957a-74122ecd3a2b.ipynb
#  7ac2572b-a8e6-454b-8798-1b1540012dd2.ipynb
#  a58bcfbc-e264-4b7b-8f2e-194c4281ff8b.ipynb
#  bd7fd133-3735-4f36-ba23-87a0601d1c19.ipynb
#  c0909394-c4fc-492d-bbfb-613cce27467e.ipynb
# 'D:\LocalData\Y108354\Documents\Плановая работа\Кузьменко\Яндекс Учеба\fff.ipynb'
# 'D:\LocalData\Y108354\Documents\Плановая работа\Кузьменко\Яндекс Учеба\ppp.ipynb'
# 'D:\LocalData\Y108354\Documents\Плановая работа\Кузьменко\Яндекс Учеба\Проект 7.ipynb'
# 'D:\LocalData\Y108354\Documents\Плановая работа\Кузьменко\Яндекс Учеба\Проект 7\proekt7.ipynb'
#  eb585f0a-b4ac-4d4d-9520-283a3dea9cd8.ipynb
#  proba111.ipynb
#  proekt11
#  Untitled.ipynb
